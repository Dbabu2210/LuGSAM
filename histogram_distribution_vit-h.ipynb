# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("/content/right_lobe_Stability_Scores_full.csv")

# %%
df = pd.DataFrame(data)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Stability_Scores', 'Prompts'], dtype='object')

# %%
x=df["Stability_Scores"]

# %%
plt.figure(figsize=(4,4))
plt.hist(x, bins = 10,color='crimson')
plt.xlim(0,1)
plt.ylim(0,100)
plt.xlabel("BPIoU", fontsize=12)
plt.ylabel("counts", fontsize=12)
plt.title("Histogram Distribution of prompt right lobe", fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data_1=pd.read_csv("/content/Right_Lobe_stability_scores.csv")
df_1=pd.DataFrame(data_1)
x_1=df_1["Right_Lobe_scores"]
plt.figure(figsize=(4,4))
plt.hist(x_1, bins = 10,color='crimson')
plt.xlim(0,1)
plt.ylim(0,100)
plt.xlabel("BPIoU", fontsize=12)
plt.ylabel("counts", fontsize=12)
plt.title("Histogram Distribution of prompt Right Lobe", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Histogram Distribution of prompt Right Lobe')

# %%
data_1.columns
# Out:
# Index(['Unnamed: 0', 'Right_Lobe_scores', 'Prompts'], dtype='object')

# %%
data_2=pd.read_csv('/content/right_lung_stability_scores (1).csv')
df_2=pd.DataFrame(data_2)
x_2=df_2["right_lung_scores"]
plt.figure(figsize=(4,4))
plt.hist(x_2, bins = 10, color='crimson')
plt.xlim(0,1)
plt.ylim(0,100)
plt.xlabel("BPIoU", fontsize=12)
plt.ylabel("counts", fontsize=12)
plt.title("Histogram Distribution of prompt right lung", fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_2.columns
# Out:
# Index(['Unnamed: 0', 'right_lung_scores', 'Prompts'], dtype='object')

# %%
data_3=pd.read_csv('/content/Right Lung scores.csv')
df_3=pd.DataFrame(data_3)
x_3=df_3["Right Lung scores"]
plt.figure(figsize=(4,4))
plt.hist(x_3, bins = 10,color='crimson')
plt.xlim(0,1)
plt.ylim(0,100)
plt.xlabel("BPIoU", fontsize=12)
plt.ylabel("counts", fontsize=12)
plt.title("Histogram Distribution of prompt Right Lung", fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_3.columns
# Out:
# Index(['Unnamed: 0', 'Right Lung scores'], dtype='object')

# %%
data_4=pd.read_csv('/content/Right . Lobe . stability_scores (2).csv')
df_4=pd.DataFrame(data_4)
x_4=df_4["Right . Lobe ."]
plt.figure(figsize=(4,4))
plt.hist(x_4, bins = 10,color='crimson')
plt.xlim(0,1)
plt.ylim(0,100)
plt.xlabel("BPIoU", fontsize=12)
plt.ylabel("counts", fontsize=12)
plt.title("Histogram Distribution of prompt Right . Lobe .", fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_4.columns
# Out:
# Index(['Unnamed: 0', 'Right . Lobe .', 'Prompts'], dtype='object')

# %%
data_5=pd.read_csv('/content/RIGHT . LOBE . stability_scores.csv')
df_5=pd.DataFrame(data_5)
x_5=df_5['RIGHT . LOBE .']
plt.figure(figsize=(4,4))
plt.hist(x_5, bins = 10,color='crimson')
plt.xlim(0,1)
plt.ylim(0,100)
plt.xlabel("BPIoU", fontsize=12)
plt.ylabel("counts", fontsize=12)
plt.title("Histogram Distribution of prompt RIGHT . LOBE .", fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_5.columns
# Out:
# Index(['Unnamed: 0', 'RIGHT . LOBE .', 'Prompts'], dtype='object')

# %%
data_6=pd.read_csv('/content/RIGHT. LUNG . scores.csv')
df_6=pd.DataFrame(data_6)
x_6=df_6["RIGHT. LUNG . scores"]
plt.figure(figsize=(4,4))
plt.hist(x_6, bins = 10,color='crimson')
plt.xlim(0,1)
plt.ylim(0,100)
plt.xlabel("BPIoU", fontsize=12)
plt.ylabel("counts", fontsize=12)
plt.title("Histogram Distribution of prompt RIGHT . LUNG .", fontsize=12)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_6.columns
# Out:
# Index(['Unnamed: 0', 'RIGHT. LUNG . scores', 'Prompts'], dtype='object')

# %%
bins=10;
plt.figure(figsize=(4,4))
plt.xlim(0,1)
plt.ylim(0,100)
plt.hist(x, bins, alpha=0.7, label='right lobe', color='blue')
plt.hist(x_1, bins, alpha=0.7, label='Right Lobe', color='red')
plt.hist(x_2, bins, alpha=0.7, label='right lung', color='green')
plt.hist(x_3, bins, alpha=0.7, label='Right Lung', color='orange')
plt.hist(x_4,bins, alpha=0.7, label='Right . Lobe .', color='crimson')
plt.hist(x_5,bins, alpha=0.7, label='RIGHT . LOBE .')
plt.hist(x_6,bins, alpha=0.7, label='RIGHT . LUNG .', color='white')
plt.xlabel("BPIoU",fontsize=12)
plt.ylabel("counts",fontsize=12)
plt.legend(loc='upper left', fontsize=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# left lobe
data_7=pd.read_csv('/content/left lobe scores.csv')
df_7=pd.DataFrame(data_7)
x_7=df_7["left lobe scores"]
plt.figure(figsize=(4,4))
plt.hist(x_7, bins = 10,color='green')
plt.xlim(0,1)
plt.ylim(0,100)
plt.xlabel("BPIoU", fontsize=12)
plt.ylabel("counts", fontsize=12)
plt.title("Histogram Distribution of prompt left lobe", fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_7.columns
# Out:
# Index(['Unnamed: 0', 'left lobe scores', 'Prompts'], dtype='object')

# %%
data_8=pd.read_csv('/content/left lung scores.csv')
df_8=pd.DataFrame(data_8)
x_8=df_8["left lung scores"]
plt.figure(figsize=(4,4))
plt.hist(x_7, bins = 10,color='green')
plt.xlim(0,1)
plt.ylim(0,100)
plt.xlabel("BPIoU", fontsize=12)
plt.ylabel("counts", fontsize=12)
plt.title("Histogram Distribution of prompt left lung", fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_8.columns
# Out:
# Index(['Unnamed: 0', 'left lung scores', 'Prompts'], dtype='object')

# %%
data_9=pd.read_csv('/content/Left Lobe scores (1).csv')
df_9=pd.DataFrame(data_9)
x_9=df_9["Left Lobe scores"]
plt.figure(figsize=(4,4))
plt.hist(x_9, bins = 10,color='green')
plt.xlim(0,1)
plt.ylim(0,100)
plt.xlabel("BPIoU", fontsize=12)
plt.ylabel("counts", fontsize=12)
plt.title("Histogram Distribution of prompt Left Lobe", fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_9.columns
# Out:
# Index(['Unnamed: 0', 'Left Lobe scores', 'Prompts'], dtype='object')

# %%
data_10=pd.read_csv("/content/Left Lung scores (1).csv")
df_10=pd.DataFrame(data_10)
x_10=df_10["Left Lung scores"]
plt.figure(figsize=(4,4))
plt.hist(x_10, bins = 10,color='green')
plt.xlim(0,1)
plt.ylim(0,100)
plt.xlabel("BPIoU", fontsize=12)
plt.ylabel("counts", fontsize=12)
plt.title("Histogram Distribution of prompt Left Lung", fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_10.columns
# Out:
# Index(['Unnamed: 0', 'Left Lung scores', 'Prompts'], dtype='object')

# %%
data_11=pd.read_csv('/content/Left . Lobe . scores.csv')
df_11=pd.DataFrame(data_11)
x_11=df_11["Left . Lobe . scores"]
plt.figure(figsize=(4,4))
plt.hist(x_11, bins = 10,color='green')
plt.xlim(0,1)
plt.ylim(0,100)
plt.xlabel("BPIoU", fontsize=12)
plt.ylabel("counts", fontsize=12)
plt.title("Histogram Distribution of prompt Left . Lobe .", fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_11.columns
# Out:
# Index(['Unnamed: 0', 'Left . Lobe . scores', 'Prompts'], dtype='object')

# %%
data_12=pd.read_csv('/content/LEFT . LOBE . scores (1).csv')
df_12=pd.DataFrame(data_12)
x_12=df_12["LEFT . LOBE . scores"]
plt.figure(figsize=(4,4))
plt.hist(x_12, bins = 10,color='green')
plt.xlim(0,1)
plt.ylim(0,100)
plt.xlabel("BPIoU", fontsize=12)
plt.ylabel("counts", fontsize=12)
plt.title("Histogram Distribution of prompt LEFT . LOBE .", fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_12.columns
# Out:
# Index(['Unnamed: 0', 'LEFT . LOBE . scores', 'Prompts'], dtype='object')

# %%
data_13=pd.read_csv('/content/LEFT . LUNG . scores.csv')
df_13=pd.DataFrame(data_13)
x_13=df_13["LEFT . LUNG . scores"]
plt.figure(figsize=(4,4))
plt.hist(x_13, bins = 10,color='green')
plt.xlim(0,1)
plt.ylim(0,100)
plt.xlabel("BPIoU", fontsize=12)
plt.ylabel("counts", fontsize=12)
plt.title("Histogram Distribution of prompt LEFT . LUNG .", fontsize=10)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_13.columns
# Out:
# Index(['Unnamed: 0', 'LEFT . LUNG . scores', 'Prompts'], dtype='object')

# %%
bins=10;
plt.figure(figsize=(4,4))
plt.xlim(0,1)
plt.ylim(0,100)
plt.hist(x_7, bins, alpha=0.1, label='left lobe', histtype='stepfilled')
plt.hist(x_8, bins, alpha=0.2, label='Left Lobe', color='green',histtype='stepfilled')
plt.hist(x_9, bins, alpha=0.2, label='left lung', histtype='stepfilled')
plt.hist(x_10, bins, alpha=0.4, label='Left Lung', color='gold' , histtype='stepfilled')
plt.hist(x_11,bins, alpha=0.1, label='Left . Lobe .', histtype='stepfilled')
plt.hist(x_12,bins, alpha=0.1, label='LEFT . LOBE .',  histtype='stepfilled')
plt.hist(x_13,bins, alpha=0.1, label='LEFT . LUNG .', color='white', histtype='stepfilled')
plt.xlabel("BPIoU",fontsize=12)
plt.ylabel("counts",fontsize=12)
plt.legend(loc='upper left', fontsize=8)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
